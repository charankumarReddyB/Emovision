# %% [markdown]
# # Emovision — Google Colab Fast GPU Model Experiments
#
# This self-contained notebook runs **Baseline**, **Experiment 1 (Class-Weighted Loss)**, and **Experiment 2 (ResNet-18 + Label Smoothing)** on Google Colab's **T4 GPU**.
#
# ### Total GPU Runtime: ~2 minutes for all 3 experiments!

# %%
# 1. Install required packages
# !pip install -q datasets scikit-learn seaborn matplotlib pandas pyarrow

import torch
print("PyTorch Version:", torch.__version__)
print("GPU Available:", torch.cuda.is_available())
if torch.cuda.is_available():
    print("GPU Device Name:", torch.cuda.get_device_name(0))
else:
    print("⚠️ Please go to Runtime -> Change runtime type -> Select T4 GPU")

# %%
# 2. Run Full Experiment Suite & Generate Comparative Table
exec(open('emovision_colab_experiments.py').read())

# %%
# 3. Download Best Trained Weights (emotion_model.pth)
from google.colab import files
files.download('best_emotion_model.pth')
